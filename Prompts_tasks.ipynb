# %% [markdown]
# Tasks:
# As an observation point, we can look into the types of input and the top predictions that would be output by each layer of the network.
# Start by solving these preliminary tasks:
# Task A - Find all the occurrences in which the object string is present in the subject, such as:
# Apple II (subject) is produced by Apple (object)
# Make a list of all the relations for which such instances occur.
# Task B - For each of the prompts whose object is 'Paris':
# Find at what layer the 'object' token is present for the first time in the top 10 tokens
# Find at what layer the 'object' token is top 1 in for the first time

# %% [markdown]
# # **Task A**

# %%
import urllib.request
import json
from io import StringIO
import requests
import pandas as pd

# %%
file_url = 'https://drive.google.com/uc?id=1htUxnapH5oPnMyaxhk-xrIE4NvLS_2MH'
prompts_file = urllib.request.urlopen(file_url)
prompts_file = prompts_file.read()
prompts_file = prompts_file.decode("utf-8")


def download_file(url, destination):
    response = requests.get(url)
    if response.status_code == 200:
        with open(destination, 'wb') as f:
            f.write(response.content)
        print("File downloaded successfully at", destination)
    else:
        print("Failed to download file")

def split_file(input_file, output_file1, output_file2):
    with open(input_file, 'r') as f:
        data = f.readlines()

    # Determine the splitting point
    split_index = len(data) // 2

    # Split the data into two parts
    part1 = data[:split_index]
    part2 = data[split_index:]

    # Write the two parts to separate output files
    with open(output_file1, 'w') as f1:
        f1.writelines(part1)

    with open(output_file2, 'w') as f2:
        f2.writelines(part2)

input_url = 'https://drive.google.com/uc?id=1htUxnapH5oPnMyaxhk-xrIE4NvLS_2MH'
output_file1 = 'output1.txt'
output_file2 = 'output2.txt'

download_file(input_url, 'input.txt')
split_file('input.txt', output_file1, output_file2)
# Out:
# File downloaded successfully at input.txt

# %%
# Read JSON data from input.txt into a DataFrame
df = pd.read_json('input.txt', lines=True)

# Display the DataFrame
print(df)
# Out:
#        obj_label             sub_label predicate_id  \
# 0     Antarctica  Shackleton Ice Shelf          P30
# 1        English    Australian English         P279
# 2        English         Welsh English         P279
# 3        English   New Zealand English         P279
# 4        English      American English         P279
# ...          ...                   ...          ...
# 1349         fat       unsaturated fat         P279
# 1350      planet     extrasolar planet         P279
# 1351     teacher          head teacher         P279
# 1352        beef           ground beef         P279
# 1353     printer         laser printer         P279
#
#                         template  acc_out  \
# 0        [X] is located in [Y] .        1
# 1     [X] is a subclass of [Y] .        1
# 2     [X] is a subclass of [Y] .        1
# 3     [X] is a subclass of [Y] .        1
# 4     [X] is a subclass of [Y] .        1
# ...                          ...      ...
# 1349  [X] is a subclass of [Y] .        1
# 1350  [X] is a subclass of [Y] .        1
# 1351  [X] is a subclass of [Y] .        1
# 1352  [X] is a subclass of [Y] .        1
# 1353  [X] is a subclass of [Y] .        1
#
#                                                topk_IDs  \
# 0     [27593, 5, 31709, 580, 10, 953, 1089, 896, 391...
# 1     [2370, 470, 1089, 5, 2059, 5787, 188, 3470, 15...
# 2     [2370, 12093, 5, 1089, 3470, 5787, 470, 19881,...
# 3     [2370, 5, 2059, 188, 470, 3470, 1089, 5787, 15...
# 4     [2370, 1089, 5, 5787, 3470, 470, 39164, 13021,...
# ...                                                 ...
# 1349  [5886, 24191, 11356, 26425, 19331, 6154, 9977,...
# 1350  [5518, 18979, 1931, 30109, 13058, 999, 5, 3079...
# 1351  [3254, 5, 471, 5402, 28665, 22, 10, 334, 2849,...
# 1352  [6829, 4884, 1255, 12072, 12094, 5884, 19464, ...
# 1353  [24079, 13443, 5, 3034, 16019, 9212, 5175, 177...
#
#                                              topk_token  \
# 0     [ Antarctica,  the,  Greenland,  West,  a,  Ea...
# 1     [ English,  American,  British,  the,  Austral...
# 2     [ English,  Welsh,  the,  British,  Old,  Stan...
# 3     [ English,  the,  Australian,  New,  American,...
# 4     [ English,  British,  the,  Standard,  Old,  A...
# ...                                                 ...
# 1349  [ fat,  saturated,  lip,  fats,  cholesterol, ...
# 1350  [ planet,  planets,  ex,  extras,  alien,  sta...
# 1351  [ teacher,  the,  head,  principal,  admin,  "...
# 1352  [ beef,  meat,  ground,  pork,  cow,  chicken,...
# 1353  [ printer,  laser,  the,  computer,  ink,  cop...
#
#                                                 int_IDs  \
# 0     {'0': [11, 15, 8, 23, 6, 13, 7, 19, 5, 9], '1'...
# 1     {'0': [9, 1116, 6, 1525, 8, 12, 11, 4, 36, 15]...
# 2     {'0': [9, 1116, 11, 6, 8, 1525, 12, 13, 7, 15]...
# 3     {'0': [9, 1116, 11, 6, 8, 1525, 12, 13, 7, 15]...
# 4     {'0': [9, 1116, 6, 1525, 8, 12, 11, 4, 36, 15]...
# ...                                                 ...
# 1349  {'0': [9, 1116, 11, 6, 8, 1525, 12, 13, 7, 15]...
# 1350  {'0': [9, 1116, 8, 6, 11, 1525, 12, 13, 7, 36]...
# 1351  {'0': [9, 1116, 6, 1525, 8, 12, 11, 4, 36, 15]...
# 1352  {'0': [9, 1116, 6, 1525, 8, 12, 11, 4, 36, 15]...
# 1353  {'0': [9, 1116, 11, 6, 8, 1525, 12, 13, 7, 15]...
#
#                                              int_tokens
# 0     {'0': [' in', ' on', ' and', ' at', ',', ' for...
# 1     {'0': [' of', 'of', ',', ' Of', ' and', '-', '...
# 2     {'0': [' of', 'of', ' in', ',', ' and', ' Of',...
# 3     {'0': [' of', 'of', ' in', ',', ' and', ' Of',...
# 4     {'0': [' of', 'of', ',', ' Of', ' and', '-', '...
# ...                                                 ...
# 1349  {'0': [' of', 'of', ' in', ',', ' and', ' Of',...
# 1350  {'0': [' of', 'of', ' and', ',', ' in', ' Of',...
# 1351  {'0': [' of', 'of', ',', ' Of', ' and', '-', '...
# 1352  {'0': [' of', 'of', ',', ' Of', ' and', '-', '...
# 1353  {'0': [' of', 'of', ' in', ',', ' and', ' Of',...
#
# [1354 rows x 9 columns]

# %%
# Obj and Sub matches
obj_labels = df['obj_label']
sub_labels = df['sub_label']
pred_id = df['predicate_id']
# List to store pairs where object string is present in subject string
matches = []
# Iterate through each row of the DataFrame
for index, row in df.iterrows():
    sub_label = row['sub_label']
    obj_label = row['obj_label']
    predicate_id = row['predicate_id']
    if obj_label in sub_label:
        matches.append((sub_label, obj_label, predicate_id))

# Print the matches
print("Occurrences where object string is present in subject string:")
for match in matches:
    print("Subject:", match[0])
    print("Object:", match[1])
    print("Predicate ID:", match[2])
    print()
# Out:
# Occurrences where object string is present in subject string:
# Subject: Australian English
# Object: English
# Predicate ID: P279
#
# Subject: Welsh English
# Object: English
# Predicate ID: P279
#
# Subject: New Zealand English
# Object: English
# Predicate ID: P279
#
# Subject: American English
# Object: English
# Predicate ID: P279
#
# Subject: Canadian English
# Object: English
# Predicate ID: P279
#
# Subject: NBC Nightside
# Object: NBC
# Predicate ID: P449
#
# Subject: Dateline NBC
# Object: NBC
# Predicate ID: P449
#
# Subject: NFL on NBC
# Object: NBC
# Predicate ID: P449
#
# Subject: NBA on NBC
# Object: NBC
# Predicate ID: P449
#
# Subject: NBC Mystery Movie
# Object: NBC
# Predicate ID: P449
#
# Subject: NBC Sunday Showcase
# Object: NBC
# Predicate ID: P449
#
# Subject: The NBC Monday Movie
# Object: NBC
# Predicate ID: P449
#
# Subject: CBS Evening News
# Object: CBS
# Predicate ID: P449
#
# Subject: CBS Storybreak
# Object: CBS
# Predicate ID: P449
#
# Subject: CBS Playhouse
# Object: CBS
# Predicate ID: P449
#
# Subject: SEC on CBS
# Object: CBS
# Predicate ID: P449
#
# Subject: CBS Morning News
# Object: CBS
# Predicate ID: P449
#
# Subject: CBS Summer Playhouse
# Object: CBS
# Predicate ID: P449
#
# Subject: NFL on CBS
# Object: CBS
# Predicate ID: P449
#
# Subject: CBS Television Quiz
# Object: CBS
# Predicate ID: P449
#
# Subject: CBS Schoolbreak Special
# Object: CBS
# Predicate ID: P449
#
# Subject: CBS This Morning
# Object: CBS
# Predicate ID: P449
#
# Subject: CBS Sports Spectacular
# Object: CBS
# Predicate ID: P449
#
# Subject: European Union
# Object: Europe
# Predicate ID: P30
#
# Subject: Central Europe
# Object: Europe
# Predicate ID: P361
#
# Subject: Southern Europe
# Object: Europe
# Predicate ID: P361
#
# Subject: French language in Canada
# Object: French
# Predicate ID: P279
#
# Subject: Toyota Etios
# Object: Toyota
# Predicate ID: P176
#
# Subject: Toyota Supra
# Object: Toyota
# Predicate ID: P176
#
# Subject: Toyota Previa
# Object: Toyota
# Predicate ID: P176
#
# Subject: Toyota Yaris Verso
# Object: Toyota
# Predicate ID: P176
#
# Subject: Toyota Dyna
# Object: Toyota
# Predicate ID: P176
#
# Subject: Toyota Tundra
# Object: Toyota
# Predicate ID: P176
#
# Subject: Toyota Mark X ZiO
# Object: Toyota
# Predicate ID: P176
#
# Subject: Toyota FJ Cruiser
# Object: Toyota
# Predicate ID: P176
#
# Subject: Toyota Tacoma
# Object: Toyota
# Predicate ID: P176
#
# Subject: Toyota Origin
# Object: Toyota
# Predicate ID: P176
#
# Subject: Toyota RAV4 EV
# Object: Toyota
# Predicate ID: P176
#
# Subject: Toyota Highlander
# Object: Toyota
# Predicate ID: P176
#
# Subject: Toyota Auris
# Object: Toyota
# Predicate ID: P176
#
# Subject: Toyota RAV4
# Object: Toyota
# Predicate ID: P176
#
# Subject: Toyota Matrix
# Object: Toyota
# Predicate ID: P176
#
# Subject: Toyota Land Cruiser
# Object: Toyota
# Predicate ID: P176
#
# Subject: Toyota Camry Solara
# Object: Toyota
# Predicate ID: P176
#
# Subject: Toyota Camry
# Object: Toyota
# Predicate ID: P176
#
# Subject: Toyota Sports 800
# Object: Toyota
# Predicate ID: P176
#
# Subject: Toyota MR2
# Object: Toyota
# Predicate ID: P176
#
# Subject: Toyota Cressida
# Object: Toyota
# Predicate ID: P176
#
# Subject: Toyota Hilux
# Object: Toyota
# Predicate ID: P176
#
# Subject: Toyota AE86
# Object: Toyota
# Predicate ID: P176
#
# Subject: Toyota Corolla
# Object: Toyota
# Predicate ID: P176
#
# Subject: Toyota ist
# Object: Toyota
# Predicate ID: P176
#
# Subject: Toyota FT-HS
# Object: Toyota
# Predicate ID: P176
#
# Subject: Toyota GT-86
# Object: Toyota
# Predicate ID: P176
#
# Subject: Toyota Mirai
# Object: Toyota
# Predicate ID: P176
#
# Subject: Toyota Cresta
# Object: Toyota
# Predicate ID: P176
#
# Subject: Toyota Celica
# Object: Toyota
# Predicate ID: P176
#
# Subject: Toyota Corona EXiV
# Object: Toyota
# Predicate ID: P176
#
# Subject: Toyota Sprinter
# Object: Toyota
# Predicate ID: P176
#
# Subject: Toyota TS010
# Object: Toyota
# Predicate ID: P176
#
# Subject: Toyota Prius
# Object: Toyota
# Predicate ID: P176
#
# Subject: Toyota Sienna
# Object: Toyota
# Predicate ID: P176
#
# Subject: Toyota Sequoia
# Object: Toyota
# Predicate ID: P176
#
# Subject: Toyota Mega Cruiser
# Object: Toyota
# Predicate ID: P176
#
# Subject: Toyota Corolla E140
# Object: Toyota
# Predicate ID: P176
#
# Subject: Toyota Avalon
# Object: Toyota
# Predicate ID: P176
#
# Subject: Toyota Starlet
# Object: Toyota
# Predicate ID: P176
#
# Subject: Toyota Avanza
# Object: Toyota
# Predicate ID: P176
#
# Subject: Toyota Tercel
# Object: Toyota
# Predicate ID: P176
#
# Subject: Toyota Vios
# Object: Toyota
# Predicate ID: P176
#
# Subject: Toyota SA
# Object: Toyota
# Predicate ID: P176
#
# Subject: Toyota Aurion
# Object: Toyota
# Predicate ID: P176
#
# Subject: Toyota Innova
# Object: Toyota
# Predicate ID: P176
#
# Subject: Toyota Carina
# Object: Toyota
# Predicate ID: P176
#
# Subject: Toyota Kijang
# Object: Toyota
# Predicate ID: P176
#
# Subject: Toyota Fortuner
# Object: Toyota
# Predicate ID: P176
#
# Subject: Toyota 2000GT
# Object: Toyota
# Predicate ID: P176
#
# Subject: Toyota Corolla Verso
# Object: Toyota
# Predicate ID: P176
#
# Subject: Toyota Land Cruiser 40 series
# Object: Toyota
# Predicate ID: P176
#
# Subject: Toyota Camry XV40
# Object: Toyota
# Predicate ID: P176
#
# Subject: Toyota G1
# Object: Toyota
# Predicate ID: P176
#
# Subject: Toyota Carina ED
# Object: Toyota
# Predicate ID: P176
#
# Subject: Toyota Land Cruiser Prado
# Object: Toyota
# Predicate ID: P176
#
# Subject: Honda Life
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda CB750
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda Concerto
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda ST1100
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda FCX
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda Vamos
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda Civic
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda Brio
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda Mobilio
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda Vigor
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda NSX
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda NSR250
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda Stream
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda Wave series
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda VFR1200F
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda CX series
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda RA272
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda Accord
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda Fireblade
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda NR500
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda Domani
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda VFR800
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda XR series
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda Civic (fifth generation)
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda Super Cub
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda FCX Clarity
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda CB400T
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda CB450
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda Civic Hybrid
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda Passport
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda CR-X
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda N360
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda Legend
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda Orthia
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda CBR600RR
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda CBX
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda S600
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda Z series
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda Shadow
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda Zoomer
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda Ballade
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda Insight
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda Prelude
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda Racing Corporation
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda Acty
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda CB900F
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda CBR600F3
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda Inspire
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda CRF series
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda ST1300
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda EV Plus
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda Civic Type R
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda City
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda HR-V
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda Ascot
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda NS500
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda RC51
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda Valkyrie
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda HSV-010 GT
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda CR-X del Sol
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda CB550
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda Civic (ninth generation)
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda Pilot
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda CBR250R
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda VFR400
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda RS125R
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda Odyssey
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda Airwave
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda S2000
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda CBR1100XX
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda CR-V
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda Fit
# Object: Honda
# Predicate ID: P176
#
# Subject: Honda Integra
# Object: Honda
# Predicate ID: P176
#
# Subject: BBC Worldwide
# Object: BBC
# Predicate ID: P127
#
# Subject: Nissan GT-R
# Object: Nissan
# Predicate ID: P176
#
# Subject: Nissan Stagea
# Object: Nissan
# Predicate ID: P176
#
# Subject: Nissan Livina Geniss
# Object: Nissan
# Predicate ID: P176
#
# Subject: Nissan Xterra
# Object: Nissan
# Predicate ID: P176
#
# Subject: Nissan Be-1
# Object: Nissan
# Predicate ID: P176
#
# Subject: Nissan Armada
# Object: Nissan
# Predicate ID: P176
#
# Subject: Nissan 300ZX
# Object: Nissan
# Predicate ID: P176
#
# Subject: Nissan Bluebird
# Object: Nissan
# Predicate ID: P176
#
# Subject: Nissan NPT-90
# Object: Nissan
# Predicate ID: P176
#
# Subject: Nissan Wingroad
# Object: Nissan
# Predicate ID: P176
#
# Subject: Nissan Sentra
# Object: Nissan
# Predicate ID: P176
#
# Subject: Nissan Cedric
# Object: Nissan
# Predicate ID: P176
#
# Subject: Nissan Elgrand
# Object: Nissan
# Predicate ID: P176
#
# Subject: Nissan Murano
# Object: Nissan
# Predicate ID: P176
#
# Subject: Nissan Sunny
# Object: Nissan
# Predicate ID: P176
#
# Subject: Nissan Quest
# Object: Nissan
# Predicate ID: P176
#
# Subject: Nissan Qashqai
# Object: Nissan
# Predicate ID: P176
#
# Subject: Nissan Pivo
# Object: Nissan
# Predicate ID: P176
#
# Subject: Nissan Caravan
# Object: Nissan
# Predicate ID: P176
#
# Subject: Nissan NX
# Object: Nissan
# Predicate ID: P176
#
# Subject: Nissan Skyline GT-R
# Object: Nissan
# Predicate ID: P176
#
# Subject: Nissan Prairie
# Object: Nissan
# Predicate ID: P176
#
# Subject: Nissan Leaf
# Object: Nissan
# Predicate ID: P176
#
# Subject: Nissan Avenir
# Object: Nissan
# Predicate ID: P176
#
# Subject: Nissan Cube
# Object: Nissan
# Predicate ID: P176
#
# Subject: Nissan 180SX
# Object: Nissan
# Predicate ID: P176
#
# Subject: Nissan R390 GT1
# Object: Nissan
# Predicate ID: P176
#
# Subject: Nissan S30
# Object: Nissan
# Predicate ID: P176
#
# Subject: Nissan Vanette
# Object: Nissan
# Predicate ID: P176
#
# Subject: Nissan Almera
# Object: Nissan
# Predicate ID: P176
#
# Subject: Nissan Bluebird
# Object: Nissan
# Predicate ID: P176
#
# Subject: Nissan Fuga
# Object: Nissan
# Predicate ID: P176
#
# Subject: Nissan 370Z
# Object: Nissan
# Predicate ID: P176
#
# Subject: Nissan GT-R LM Nismo
# Object: Nissan
# Predicate ID: P176
#
# Subject: Nissan Teana
# Object: Nissan
# Predicate ID: P176
#
# Subject: Nissan Silvia
# Object: Nissan
# Predicate ID: P176
#
# Subject: Nissan Skyline
# Object: Nissan
# Predicate ID: P176
#
# Subject: Nissan Juke
# Object: Nissan
# Predicate ID: P176
#
# Subject: Nissan NV200
# Object: Nissan
# Predicate ID: P176
#
# Subject: Nissan Z-car
# Object: Nissan
# Predicate ID: P176
#
# Subject: Nissan Lafesta
# Object: Nissan
# Predicate ID: P176
#
# Subject: Nissan Patrol
# Object: Nissan
# Predicate ID: P176
#
# Subject: Nissan Civilian
# Object: Nissan
# Predicate ID: P176
#
# Subject: Nissan Navara
# Object: Nissan
# Predicate ID: P176
#
# Subject: Nissan Laurel
# Object: Nissan
# Predicate ID: P176
#
# Subject: Nissan X-Trail
# Object: Nissan
# Predicate ID: P176
#
# Subject: Nissan S130
# Object: Nissan
# Predicate ID: P176
#
# Subject: Nissan 200SX
# Object: Nissan
# Predicate ID: P176
#
# Subject: Nissan Latio
# Object: Nissan
# Predicate ID: P176
#
# Subject: Nissan Cima
# Object: Nissan
# Predicate ID: P176
#
# Subject: Nissan R'nessa
# Object: Nissan
# Predicate ID: P176
#
# Subject: Nissan R89C
# Object: Nissan
# Predicate ID: P176
#
# Subject: Nissan Pao
# Object: Nissan
# Predicate ID: P176
#
# Subject: Nissan Serena
# Object: Nissan
# Predicate ID: P176
#
# Subject: Nissan Crew
# Object: Nissan
# Predicate ID: P176
#
# Subject: Nissan Pathfinder
# Object: Nissan
# Predicate ID: P176
#
# Subject: Nissan Primera
# Object: Nissan
# Predicate ID: P176
#
# Subject: Nissan R391
# Object: Nissan
# Predicate ID: P176
#
# Subject: Nissan Terrano II
# Object: Nissan
# Predicate ID: P176
#
# Subject: Nissan Prince Royal
# Object: Nissan
# Predicate ID: P176
#
# Subject: Nissan Caball
# Object: Nissan
# Predicate ID: P176
#
# Subject: Nissan Motor Manufacturing UK
# Object: Nissan
# Predicate ID: P127
#
# Subject: Russian Science Citation Index
# Object: Russian
# Predicate ID: P407
#
# Subject: Russian Wikipedia
# Object: Russian
# Predicate ID: P407
#
# Subject: Fiat Tipo
# Object: Fiat
# Predicate ID: P176
#
# Subject: Fiat 500X
# Object: Fiat
# Predicate ID: P176
#
# Subject: Fiat 500
# Object: Fiat
# Predicate ID: P176
#
# Subject: Fiat 501
# Object: Fiat
# Predicate ID: P176
#
# Subject: Fiat Strada
# Object: Fiat
# Predicate ID: P176
#
# Subject: BMW 5 Series Gran Turismo
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW N54
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW 7 F01 F02
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW M30
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW E65
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW Z1
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW 4 Series
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW 3 Series
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW E24
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW X5
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW M5
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW E9
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW M70
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW i8
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW X1
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW 328
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW 3 Series
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW 303
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW 003
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW Z3
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW 503
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW M6
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW Z4 E85
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW 3 Series (E46)
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW 5 Series
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW E32
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW New Class
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW E87
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW M52
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW X3
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW 3 Series
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW X5
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW i3
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW IIIa
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW 1 Series
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW R32
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW M50
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW Z4
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW M3
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW 3 Series
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW M54
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW ActiveE
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW M1
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW M60
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW 6 Series
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW E38
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW E23
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW Z4 (E89)
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW X Models
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW 326
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW Hydrogen 7
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW M62
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW 801
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW Dixi
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW X6
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW 700
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW 5 Series
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW N52
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW 7 Series
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW New Six
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW M40
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW 501
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW S65
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW M Coupe
# Object: BMW
# Predicate ID: P176
#
# Subject: BMW Motorrad
# Object: BMW
# Predicate ID: P127
#
# Subject: BMW M
# Object: BMW
# Predicate ID: P127
#
# Subject: MTV Cribs
# Object: MTV
# Predicate ID: P449
#
# Subject: Club MTV
# Object: MTV
# Predicate ID: P449
#
# Subject: Oddville, MTV
# Object: MTV
# Predicate ID: P449
#
# Subject: MTV Sports
# Object: MTV
# Predicate ID: P449
#
# Subject: Google Authenticator
# Object: Google
# Predicate ID: P176
#
# Subject: Google Answers
# Object: Google
# Predicate ID: P127
#
# Subject: Google Developers
# Object: Google
# Predicate ID: P127
#
# Subject: Google Maps
# Object: Google
# Predicate ID: P127
#
# Subject: Google Images
# Object: Google
# Predicate ID: P127
#
# Subject: Google Street View
# Object: Google
# Predicate ID: P127
#
# Subject: Google Pay Send
# Object: Google
# Predicate ID: P127
#
# Subject: Google Account
# Object: Google
# Predicate ID: P127
#
# Subject: Google Groups
# Object: Google
# Predicate ID: P127
#
# Subject: Google AdSense
# Object: Google
# Predicate ID: P127
#
# Subject: Googleplex
# Object: Google
# Predicate ID: P127
#
# Subject: Google Image Labeler
# Object: Google
# Predicate ID: P127
#
# Subject: iGoogle
# Object: Google
# Predicate ID: P127
#
# Subject: Google Sites
# Object: Google
# Predicate ID: P127
#
# Subject: Google Earth
# Object: Google
# Predicate ID: P127
#
# Subject: Google Ads
# Object: Google
# Predicate ID: P127
#
# Subject: Google Videos
# Object: Google
# Predicate ID: P127
#
# Subject: Google Code Search
# Object: Google
# Predicate ID: P127
#
# Subject: Google Labs
# Object: Google
# Predicate ID: P127
#
# Subject: Google Patents
# Object: Google
# Predicate ID: P127
#
# Subject: Google Drive
# Object: Google
# Predicate ID: P127
#
# Subject: Google Voice
# Object: Google
# Predicate ID: P127
#
# Subject: Google Health
# Object: Google
# Predicate ID: P127
#
# Subject: Google Marketing Platform
# Object: Google
# Predicate ID: P127
#
# Subject: Google Shopping
# Object: Google
# Predicate ID: P127
#
# Subject: Google Books
# Object: Google
# Predicate ID: P127
#
# Subject: Google Buzz
# Object: Google
# Predicate ID: P127
#
# Subject: Google News
# Object: Google
# Predicate ID: P127
#
# Subject: Google Map Maker
# Object: Google
# Predicate ID: P127
#
# Subject: Google Trends
# Object: Google
# Predicate ID: P127
#
# Subject: Google Finance
# Object: Google
# Predicate ID: P127
#
# Subject: Google Custom Search
# Object: Google
# Predicate ID: P127
#
# Subject: Google Translate
# Object: Google
# Predicate ID: P127
#
# Subject: Google Cloud Storage
# Object: Google
# Predicate ID: P127
#
# Subject: Google Reader
# Object: Google
# Predicate ID: P127
#
# Subject: Google Contacts
# Object: Google
# Predicate ID: P127
#
# Subject: Google Person Finder
# Object: Google
# Predicate ID: P127
#
# Subject: Google Arts & Culture
# Object: Google
# Predicate ID: P127
#
# Subject: Google Now
# Object: Google
# Predicate ID: P127
#
# Subject: Google Keep
# Object: Google
# Predicate ID: P127
#
# Subject: Google Alerts
# Object: Google
# Predicate ID: P127
#
# Subject: Google Scholar
# Object: Google
# Predicate ID: P127
#
# Subject: Boston Film Festival
# Object: Boston
# Predicate ID: P276
#
# Subject: Central Africa
# Object: Africa
# Predicate ID: P361
#
# Subject: HBO World Championship Boxing
# Object: HBO
# Predicate ID: P449
#
# Subject: Chevrolet Monte Carlo
# Object: Chevrolet
# Predicate ID: P176
#
# Subject: Toronto International Film Festival
# Object: Toronto
# Predicate ID: P276
#
# Subject: CGTN Spanish
# Object: Spanish
# Predicate ID: P407
#
# Subject: Renault Vel Satis
# Object: Renault
# Predicate ID: P176
#
# Subject: Renault Safrane
# Object: Renault
# Predicate ID: P176
#
# Subject: Renault 14
# Object: Renault
# Predicate ID: P176
#
# Subject: Renault 12
# Object: Renault
# Predicate ID: P176
#
# Subject: Renault Twingo
# Object: Renault
# Predicate ID: P176
#
# Subject: Renault 4
# Object: Renault
# Predicate ID: P176
#
# Subject: Renault 25
# Object: Renault
# Predicate ID: P176
#
# Subject: Renault 19
# Object: Renault
# Predicate ID: P176
#
# Subject: Renault Dauphine
# Object: Renault
# Predicate ID: P176
#
# Subject: Renault 4CV
# Object: Renault
# Predicate ID: P176
#
# Subject: Renault Symbol
# Object: Renault
# Predicate ID: P176
#
# Subject: Renault Avantime
# Object: Renault
# Predicate ID: P176
#
# Subject: Renault 16
# Object: Renault
# Predicate ID: P176
#
# Subject: Renault Modus
# Object: Renault
# Predicate ID: P176
#
# Subject: Renault Koleos
# Object: Renault
# Predicate ID: P176
#
# Subject: Renault 8
# Object: Renault
# Predicate ID: P176
#
# Subject: Renault Alpine A442
# Object: Renault
# Predicate ID: P176
#
# Subject: Renault Twizy
# Object: Renault
# Predicate ID: P176
#
# Subject: Renault 4P
# Object: Renault
# Predicate ID: P176
#
# Subject: Renault Wind
# Object: Renault
# Predicate ID: P176
#
# Subject: Renault 18
# Object: Renault
# Predicate ID: P176
#
# Subject: Renault Captur
# Object: Renault
# Predicate ID: P176
#
# Subject: Renault Juvaquatre
# Object: Renault
# Predicate ID: P176
#
# Subject: Renault 5
# Object: Renault
# Predicate ID: P176
#
# Subject: Renault Clio
# Object: Renault
# Predicate ID: P176
#
# Subject: Renault Sport Spider
# Object: Renault
# Predicate ID: P176
#
# Subject: Renault Fluence
# Object: Renault
# Predicate ID: P176
#
# Subject: Renault 5 Turbo
# Object: Renault
# Predicate ID: P176
#
# Subject: Renault Espace
# Object: Renault
# Predicate ID: P176
#
# Subject: Renault Kangoo
# Object: Renault
# Predicate ID: P176
#
# Subject: Renault Trafic
# Object: Renault
# Predicate ID: P176
#
# Subject: Renault Estafette
# Object: Renault
# Predicate ID: P176
#
# Subject: Renault Fuego
# Object: Renault
# Predicate ID: P176
#
# Subject: Renault R26
# Object: Renault
# Predicate ID: P176
#
# Subject: Renault Talisman
# Object: Renault
# Predicate ID: P176
#
# Subject: Renault Laguna
# Object: Renault
# Predicate ID: P176
#
# Subject: Oyak-Renault
# Object: Renault
# Predicate ID: P127
#
# Subject: Tokyo International Film Festival
# Object: Tokyo
# Predicate ID: P276
#
# Subject: Melbourne International Film Festival
# Object: Melbourne
# Predicate ID: P276
#
# Subject: Melbourne International Comedy Festival
# Object: Melbourne
# Predicate ID: P276
#
# Subject: Sony NEX-5
# Object: Sony
# Predicate ID: P176
#
# Subject: Sony NEX-7
# Object: Sony
# Predicate ID: P176
#
# Subject: Sony Alpha 77
# Object: Sony
# Predicate ID: P176
#
# Subject: Sony camcorders
# Object: Sony
# Predicate ID: P176
#
# Subject: Sony Alpha 99
# Object: Sony
# Predicate ID: P176
#
# Subject: Sony Mavica
# Object: Sony
# Predicate ID: P176
#
# Subject: Sony SLT camera
# Object: Sony
# Predicate ID: P176
#
# Subject: Sony E-mount
# Object: Sony
# Predicate ID: P176
#
# Subject: Sony Alpha 900
# Object: Sony
# Predicate ID: P176
#
# Subject: Sony Interactive Entertainment
# Object: Sony
# Predicate ID: P127
#
# Subject: Sony Pictures
# Object: Sony
# Predicate ID: P127
#
# Subject: Sony/ATV Music Publishing
# Object: Sony
# Predicate ID: P127
#
# Subject: Sony Crackle
# Object: Sony
# Predicate ID: P127
#
# Subject: Sony Music Entertainment Japan
# Object: Sony
# Predicate ID: P127
#
# Subject: Sony Pictures Television
# Object: Sony
# Predicate ID: P127
#
# Subject: Sony Pictures Entertainment Japan
# Object: Sony
# Predicate ID: P127
#
# Subject: Dodge Power Wagon
# Object: Dodge
# Predicate ID: P176
#
# Subject: Harold Lever, Baron Lever of Manchester
# Object: Manchester
# Predicate ID: P19
#
# Subject: Nokia Lumia 800
# Object: Nokia
# Predicate ID: P176
#
# Subject: Nokia Lumia 900
# Object: Nokia
# Predicate ID: P176
#
# Subject: Nokia 1100
# Object: Nokia
# Predicate ID: P176
#
# Subject: Nokia Lumia 630
# Object: Nokia
# Predicate ID: P176
#
# Subject: Nokia N810
# Object: Nokia
# Predicate ID: P176
#
# Subject: Nokia 5800 XpressMusic
# Object: Nokia
# Predicate ID: P176
#
# Subject: Nokia N8
# Object: Nokia
# Predicate ID: P176
#
# Subject: Nokia Lumia 925
# Object: Nokia
# Predicate ID: P176
#
# Subject: Nokia E72
# Object: Nokia
# Predicate ID: P176
#
# Subject: Nokia E71
# Object: Nokia
# Predicate ID: P176
#
# Subject: Nokia N900
# Object: Nokia
# Predicate ID: P176
#
# Subject: Nokia Lumia 1020
# Object: Nokia
# Predicate ID: P176
#
# Subject: Nokia N73
# Object: Nokia
# Predicate ID: P176
#
# Subject: Nokia C7-00
# Object: Nokia
# Predicate ID: P176
#
# Subject: Nokia N85
# Object: Nokia
# Predicate ID: P176
#
# Subject: Nokia N82
# Object: Nokia
# Predicate ID: P176
#
# Subject: Nokia N80
# Object: Nokia
# Predicate ID: P176
#
# Subject: Nokia Asha 501
# Object: Nokia
# Predicate ID: P176
#
# Subject: Nokia 3310
# Object: Nokia
# Predicate ID: P176
#
# Subject: Nokia 808 PureView
# Object: Nokia
# Predicate ID: P176
#
# Subject: Nokia 8800
# Object: Nokia
# Predicate ID: P176
#
# Subject: Nokia N9
# Object: Nokia
# Predicate ID: P176
#
# Subject: Nokia N800
# Object: Nokia
# Predicate ID: P176
#
# Subject: Nokia Lumia 920
# Object: Nokia
# Predicate ID: P176
#
# Subject: Nokia 6233
# Object: Nokia
# Predicate ID: P176
#
# Subject: Nokia Lumia 710
# Object: Nokia
# Predicate ID: P176
#
# Subject: Nokia Lumia 1520
# Object: Nokia
# Predicate ID: P176
#
# Subject: Nokia N70
# Object: Nokia
# Predicate ID: P176
#
# Subject: Nokia Internet tablet
# Object: Nokia
# Predicate ID: P176
#
# Subject: Nokia Lumia 520
# Object: Nokia
# Predicate ID: P176
#
# Subject: Nokia Lumia 820
# Object: Nokia
# Predicate ID: P176
#
# Subject: Ferrari 212 Inter
# Object: Ferrari
# Predicate ID: P176
#
# Subject: Ferrari 195 Inter
# Object: Ferrari
# Predicate ID: P176
#
# Subject: Ferrari F12 berlinetta
# Object: Ferrari
# Predicate ID: P176
#
# Subject: Ferrari 458
# Object: Ferrari
# Predicate ID: P176
#
# Subject: Ferrari F40
# Object: Ferrari
# Predicate ID: P176
#
# Subject: Ferrari 125 F1
# Object: Ferrari
# Predicate ID: P176
#
# Subject: Ferrari 166 S
# Object: Ferrari
# Predicate ID: P176
#
# Subject: Ferrari 333 SP
# Object: Ferrari
# Predicate ID: P176
#
# Subject: Ferrari 375 F1
# Object: Ferrari
# Predicate ID: P176
#
# Subject: Ferrari 312PB
# Object: Ferrari
# Predicate ID: P176
#
# Subject: Ferrari 575M Maranello
# Object: Ferrari
# Predicate ID: P176
#
# Subject: Ferrari Berlinetta Boxer
# Object: Ferrari
# Predicate ID: P176
#
# Subject: LaFerrari
# Object: Ferrari
# Predicate ID: P176
#
# Subject: Ferrari 365
# Object: Ferrari
# Predicate ID: P176
#
# Subject: Ferrari 550
# Object: Ferrari
# Predicate ID: P176
#
# Subject: Ferrari 599 GTB Fiorano
# Object: Ferrari
# Predicate ID: P176
#
# Subject: Ferrari 375 MM
# Object: Ferrari
# Predicate ID: P176
#
# Subject: Ferrari 612 Scaglietti
# Object: Ferrari
# Predicate ID: P176
#
# Subject: Ferrari F355
# Object: Ferrari
# Predicate ID: P176
#
# Subject: Ferrari 288 GTO
# Object: Ferrari
# Predicate ID: P176
#
# Subject: Ferrari 246 F1
# Object: Ferrari
# Predicate ID: P176
#
# Subject: Ferrari 250 GTO
# Object: Ferrari
# Predicate ID: P176
#
# Subject: Ferrari 158
# Object: Ferrari
# Predicate ID: P176
#
# Subject: Ferrari 348
# Object: Ferrari
# Predicate ID: P176
#
# Subject: Ferrari F430
# Object: Ferrari
# Predicate ID: P176
#
# Subject: Ferrari 156 F1
# Object: Ferrari
# Predicate ID: P176
#
# Subject: Microsoft Band
# Object: Microsoft
# Predicate ID: P176
#
# Subject: Microsoft Developer Network
# Object: Microsoft
# Predicate ID: P127
#
# Subject: Microsoft TechNet
# Object: Microsoft
# Predicate ID: P127
#
# Subject: Microsoft account
# Object: Microsoft
# Predicate ID: P127
#
# Subject: Microsoft Research
# Object: Microsoft
# Predicate ID: P361
#
# Subject: 68th Venice International Film Festival
# Object: Venice
# Predicate ID: P276
#
# Subject: 64th Venice International Film Festival
# Object: Venice
# Predicate ID: P276
#
# Subject: Apple II series
# Object: Apple
# Predicate ID: P176
#
# Subject: Apple III
# Object: Apple
# Predicate ID: P176
#
# Subject: Apple I
# Object: Apple
# Predicate ID: P176
#
# Subject: Apple IIGS
# Object: Apple
# Predicate ID: P176
#
# Subject: Apple IIe Card
# Object: Apple
# Predicate ID: P176
#
# Subject: Apple II
# Object: Apple
# Predicate ID: P176
#
# Subject: Apple Store Online
# Object: Apple
# Predicate ID: P127
#
# Subject: ESPN Major League Soccer
# Object: ESPN
# Predicate ID: P449
#
# Subject: ESPN Major League Baseball
# Object: ESPN
# Predicate ID: P449
#
# Subject: biophysics
# Object: physics
# Predicate ID: P361
#
# Subject: radiophysics
# Object: physics
# Predicate ID: P361
#
# Subject: Audi 80
# Object: Audi
# Predicate ID: P176
#
# Subject: Audi A8
# Object: Audi
# Predicate ID: P176
#
# Subject: Audi A1
# Object: Audi
# Predicate ID: P176
#
# Subject: Audi R8R
# Object: Audi
# Predicate ID: P176
#
# Subject: Audi RSQ
# Object: Audi
# Predicate ID: P176
#
# Subject: Audi e-tron
# Object: Audi
# Predicate ID: P176
#
# Subject: Audi RS 4
# Object: Audi
# Predicate ID: P176
#
# Subject: Audi Q7
# Object: Audi
# Predicate ID: P176
#
# Subject: Audi TT
# Object: Audi
# Predicate ID: P176
#
# Subject: Audi R10 TDI
# Object: Audi
# Predicate ID: P176
#
# Subject: Audi V8
# Object: Audi
# Predicate ID: P176
#
# Subject: Audi RS 2 Avant
# Object: Audi
# Predicate ID: P176
#
# Subject: Audi S5
# Object: Audi
# Predicate ID: P176
#
# Subject: Audi R18
# Object: Audi
# Predicate ID: P176
#
# Subject: Audi 100
# Object: Audi
# Predicate ID: P176
#
# Subject: Audi S4
# Object: Audi
# Predicate ID: P176
#
# Subject: Audi A2
# Object: Audi
# Predicate ID: P176
#
# Subject: Audi R8C
# Object: Audi
# Predicate ID: P176
#
# Subject: Audi R15 TDI
# Object: Audi
# Predicate ID: P176
#
# Subject: Audi Quattro
# Object: Audi
# Predicate ID: P176
#
# Subject: Audi R8
# Object: Audi
# Predicate ID: P176
#
# Subject: Audi A6 allroad quattro
# Object: Audi
# Predicate ID: P176
#
# Subject: Audi Le Mans quattro
# Object: Audi
# Predicate ID: P176
#
# Subject: Audi A7
# Object: Audi
# Predicate ID: P176
#
# Subject: Audi F103
# Object: Audi
# Predicate ID: P176
#
# Subject: Audi RS 6
# Object: Audi
# Predicate ID: P176
#
# Subject: Audi R8
# Object: Audi
# Predicate ID: P176
#
# Subject: The Dubliners
# Object: Dublin
# Predicate ID: P740
#
# Subject: Brooklyn Film Festival
# Object: Brooklyn
# Predicate ID: P276
#
# Subject: Suzuki SV 650
# Object: Suzuki
# Predicate ID: P176
#
# Subject: Suzuki Jimny
# Object: Suzuki
# Predicate ID: P176
#
# Subject: Suzuki Aerio
# Object: Suzuki
# Predicate ID: P176
#
# Subject: Suzuki GT750
# Object: Suzuki
# Predicate ID: P176
#
# Subject: Suzuki GSV-R
# Object: Suzuki
# Predicate ID: P176
#
# Subject: Suzuki Kizashi
# Object: Suzuki
# Predicate ID: P176
#
# Subject: Suzuki RGV500
# Object: Suzuki
# Predicate ID: P176
#
# Subject: Suzuki Ertiga
# Object: Suzuki
# Predicate ID: P176
#
# Subject: Suzuki Ignis
# Object: Suzuki
# Predicate ID: P176
#
# Subject: Suzuki B-King
# Object: Suzuki
# Predicate ID: P176
#
# Subject: Suzuki GSX-R750
# Object: Suzuki
# Predicate ID: P176
#
# Subject: Suzuki Cultus Crescent
# Object: Suzuki
# Predicate ID: P176
#
# Subject: Suzuki Hayabusa
# Object: Suzuki
# Predicate ID: P176
#
# Subject: Suzuki Intruder
# Object: Suzuki
# Predicate ID: P176
#
# Subject: Suzuki Swift
# Object: Suzuki
# Predicate ID: P176
#
# Subject: Suzuki Carry
# Object: Suzuki
# Predicate ID: P176
#
# Subject: Suzuki MR Wagon
# Object: Suzuki
# Predicate ID: P176
#
# Subject: Suzuki Cervo
# Object: Suzuki
# Predicate ID: P176
#
# Subject: Suzuki Alto
# Object: Suzuki
# Predicate ID: P176
#
# Subject: Suzuki GSX-R1000
# Object: Suzuki
# Predicate ID: P176
#
# Subject: Suzuki APV
# Object: Suzuki
# Predicate ID: P176
#
# Subject: Suzuki GSX-R series
# Object: Suzuki
# Predicate ID: P176
#
# Subject: Suzuki Cappuccino
# Object: Suzuki
# Predicate ID: P176
#
# Subject: Suzuki Wagon R
# Object: Suzuki
# Predicate ID: P176
#
# Subject: Suzuki Escudo
# Object: Suzuki
# Predicate ID: P176
#
# Subject: Magyar Suzuki
# Object: Suzuki
# Predicate ID: P127
#
# Subject: Sydney Harbour Bridge
# Object: Sydney
# Predicate ID: P131
#
# Subject: 2004 Madrid train bombings
# Object: Madrid
# Predicate ID: P276
#
# Subject: Madrid Conference of 1991
# Object: Madrid
# Predicate ID: P276
#
# Subject: advanced mathematics
# Object: mathematics
# Predicate ID: P279
#
# Subject: Nintendo DS Lite
# Object: Nintendo
# Predicate ID: P176
#
# Subject: Nintendo 3DS
# Object: Nintendo
# Predicate ID: P176
#
# Subject: Nintendo DS
# Object: Nintendo
# Predicate ID: P176
#
# Subject: Nintendo Entertainment System
# Object: Nintendo
# Predicate ID: P176
#
# Subject: New Nintendo 3DS
# Object: Nintendo
# Predicate ID: P176
#
# Subject: Super Nintendo Entertainment System
# Object: Nintendo
# Predicate ID: P176
#
# Subject: Nintendo 2DS
# Object: Nintendo
# Predicate ID: P176
#
# Subject: Nintendo Entertainment Analysis & Development
# Object: Nintendo
# Predicate ID: P127
#
# Subject: Nintendo Software Planning & Development
# Object: Nintendo
# Predicate ID: P127
#
# Subject: Nintendo Network Service Development
# Object: Nintendo
# Predicate ID: P127
#
# Subject: Nintendo Software Technology
# Object: Nintendo
# Predicate ID: P127
#
# Subject: Hamburg International Film Festival
# Object: Hamburg
# Predicate ID: P276
#
# Subject: Vancouver International Film Festival
# Object: Vancouver
# Predicate ID: P276
#
# Subject: Porsche 910
# Object: Porsche
# Predicate ID: P176
#
# Subject: Porsche Panamera
# Object: Porsche
# Predicate ID: P176
#
# Subject: Porsche 911
# Object: Porsche
# Predicate ID: P176
#
# Subject: Porsche 911 GT2
# Object: Porsche
# Predicate ID: P176
#
# Subject: Porsche 356
# Object: Porsche
# Predicate ID: P176
#
# Subject: Porsche 911 GT3
# Object: Porsche
# Predicate ID: P176
#
# Subject: Porsche 996
# Object: Porsche
# Predicate ID: P176
#
# Subject: Porsche 944
# Object: Porsche
# Predicate ID: P176
#
# Subject: Porsche 930
# Object: Porsche
# Predicate ID: P176
#
# Subject: Porsche 959
# Object: Porsche
# Predicate ID: P176
#
# Subject: Porsche 997
# Object: Porsche
# Predicate ID: P176
#
# Subject: Porsche 550
# Object: Porsche
# Predicate ID: P176
#
# Subject: Porsche 906
# Object: Porsche
# Predicate ID: P176
#
# Subject: Porsche 919 Hybrid
# Object: Porsche
# Predicate ID: P176
#
# Subject: Porsche 908
# Object: Porsche
# Predicate ID: P176
#
# Subject: Porsche Cayenne
# Object: Porsche
# Predicate ID: P176
#
# Subject: Porsche 936
# Object: Porsche
# Predicate ID: P176
#
# Subject: Porsche 911 GT1
# Object: Porsche
# Predicate ID: P176
#
# Subject: Porsche 804
# Object: Porsche
# Predicate ID: P176
#
# Subject: Porsche 904
# Object: Porsche
# Predicate ID: P176
#
# Subject: Porsche Carrera
# Object: Porsche
# Predicate ID: P176
#
# Subject: Porsche 993
# Object: Porsche
# Predicate ID: P176
#
# Subject: Porsche 962
# Object: Porsche
# Predicate ID: P176
#
# Subject: Porsche Boxster
# Object: Porsche
# Predicate ID: P176
#
# Subject: Porsche 914
# Object: Porsche
# Predicate ID: P176
#
# Subject: Porsche Carrera GT
# Object: Porsche
# Predicate ID: P176
#
# Subject: 2006 Mumbai train bombings
# Object: Mumbai
# Predicate ID: P276
#
# Subject: Boeing 777
# Object: Boeing
# Predicate ID: P176
#
# Subject: Boeing 367-80
# Object: Boeing
# Predicate ID: P176
#
# Subject: Boeing 601
# Object: Boeing
# Predicate ID: P176
#
# Subject: Boeing KC-46
# Object: Boeing
# Predicate ID: P176
#
# Subject: Boeing Commercial Airplanes
# Object: Boeing
# Predicate ID: P127
#
# Subject: Boeing Defense, Space & Security
# Object: Boeing
# Predicate ID: P127
#
# Subject: Boeing Phantom Works
# Object: Boeing
# Predicate ID: P127
#
# Subject: Boeing Helicopters
# Object: Boeing
# Predicate ID: P127
#
# Subject: Cadillac Fleetwood Brougham
# Object: Cadillac
# Predicate ID: P176
#
# Subject: Cadillac Sixty Special
# Object: Cadillac
# Predicate ID: P176
#
# Subject: Cadillac Series 355
# Object: Cadillac
# Predicate ID: P176
#
# Subject: Space Center Houston
# Object: Houston
# Predicate ID: P276
#
# Subject: Italian Wikipedia
# Object: Italian
# Predicate ID: P407
#
# Subject: IBM 407
# Object: IBM
# Predicate ID: P176
#
# Subject: IBM 402
# Object: IBM
# Predicate ID: P176
#
# Subject: IBM RAD6000
# Object: IBM
# Predicate ID: P176
#
# Subject: IBM 1710
# Object: IBM
# Predicate ID: P176
#
# Subject: IBM 5100
# Object: IBM
# Predicate ID: P176
#
# Subject: IBM 9370
# Object: IBM
# Predicate ID: P176
#
# Subject: IBM Personal Computer
# Object: IBM
# Predicate ID: P176
#
# Subject: IBM 3790
# Object: IBM
# Predicate ID: P176
#
# Subject: IBM AP-101
# Object: IBM
# Predicate ID: P176
#
# Subject: IBM 7030 Stretch
# Object: IBM
# Predicate ID: P176
#
# Subject: IBM 2780/3780
# Object: IBM
# Predicate ID: P176
#
# Subject: IBM 704
# Object: IBM
# Predicate ID: P176
#
# Subject: IBM 729
# Object: IBM
# Predicate ID: P176
#
# Subject: IBM 8100
# Object: IBM
# Predicate ID: P176
#
# Subject: IBM 6150 RT
# Object: IBM
# Predicate ID: P176
#
# Subject: IBM 5120
# Object: IBM
# Predicate ID: P176
#
# Subject: IBM Research
# Object: IBM
# Predicate ID: P361
#
# Subject: Dallas International Film Festival
# Object: Dallas
# Predicate ID: P276
#
# Subject: Standard German
# Object: German
# Predicate ID: P279
#
# Subject: Volvo C30
# Object: Volvo
# Predicate ID: P176
#
# Subject: Volvo 200 Series
# Object: Volvo
# Predicate ID: P176
#
# Subject: Volvo S40
# Object: Volvo
# Predicate ID: P176
#
# Subject: Volvo 140 Series
# Object: Volvo
# Predicate ID: P176
#
# Subject: Volvo S70
# Object: Volvo
# Predicate ID: P176
#
# Subject: Volvo S80
# Object: Volvo
# Predicate ID: P176
#
# Subject: Volvo Duett
# Object: Volvo
# Predicate ID: P176
#
# Subject: Volvo 900 Series
# Object: Volvo
# Predicate ID: P176
#
# Subject: Volvo 850
# Object: Volvo
# Predicate ID: P176
#
# Subject: Volvo 300 Series
# Object: Volvo
# Predicate ID: P176
#
# Subject: Volvo 66
# Object: Volvo
# Predicate ID: P176
#
# Subject: Volvo V70
# Object: Volvo
# Predicate ID: P176
#
# Subject: Volvo 480
# Object: Volvo
# Predicate ID: P176
#
# Subject: Volvo XC90
# Object: Volvo
# Predicate ID: P176
#
# Subject: Volvo C70
# Object: Volvo
# Predicate ID: P176
#
# Subject: Volvo Trucks
# Object: Volvo
# Predicate ID: P127
#
# Subject: Miami International Film Festival
# Object: Miami
# Predicate ID: P276
#
# Subject: 2009 Shanghai Masters
# Object: Shanghai
# Predicate ID: P276
#
# Subject: CNN Presents
# Object: CNN
# Predicate ID: P449
#
# Subject: CNN Heroes
# Object: CNN
# Predicate ID: P449
#
# Subject: social philosophy
# Object: philosophy
# Predicate ID: P279
#
# Subject: philosophy of education
# Object: philosophy
# Predicate ID: P279
#
# Subject: food chemistry
# Object: chemistry
# Predicate ID: P279
#
# Subject: Middle Chinese
# Object: Chinese
# Predicate ID: P279
#
# Subject: Waxiang Chinese
# Object: Chinese
# Predicate ID: P279
#
# Subject: varieties of Chinese
# Object: Chinese
# Predicate ID: P279
#
# Subject: contemporary history
# Object: history
# Predicate ID: P279
#
# Subject: art history
# Object: history
# Predicate ID: P279
#
# Subject: local history
# Object: history
# Predicate ID: P279
#
# Subject: modern history
# Object: history
# Predicate ID: P279
#
# Subject: Middle Dutch
# Object: Dutch
# Predicate ID: P279
#
# Subject: Old Dutch
# Object: Dutch
# Predicate ID: P279
#
# Subject: Yahoo Answers
# Object: Yahoo
# Predicate ID: P127
#
# Subject: Yahoo! HotJobs
# Object: Yahoo
# Predicate ID: P127
#
# Subject: Yahoo! Music
# Object: Yahoo
# Predicate ID: P127
#
# Subject: Greek name
# Object: Greek
# Predicate ID: P407
#
# Subject: Vienna bread
# Object: bread
# Predicate ID: P279
#
# Subject: white bread
# Object: bread
# Predicate ID: P279
#
# Subject: 2002 Karachi bus bombing
# Object: Karachi
# Predicate ID: P276
#
# Subject: Chrysler K platform
# Object: Chrysler
# Predicate ID: P176
#
# Subject: Chrysler 200
# Object: Chrysler
# Predicate ID: P176
#
# Subject: Chrysler 3.3 & 3.8 engine
# Object: Chrysler
# Predicate ID: P176
#
# Subject: Chrysler 300C
# Object: Chrysler
# Predicate ID: P176
#
# Subject: Amazon S3
# Object: Amazon
# Predicate ID: P127
#
# Subject: Amazon Kindle
# Object: Amazon
# Predicate ID: P127
#
# Subject: Amazon Web Services
# Object: Amazon
# Predicate ID: P127
#
# Subject: Amazon Music
# Object: Amazon
# Predicate ID: P127
#
# Subject: Sky Movies Box Office
# Object: Sky
# Predicate ID: P127
#
# Subject: Sky Sports Racing
# Object: Sky
# Predicate ID: P127
#
# Subject: pea soup
# Object: soup
# Predicate ID: P279
#
# Subject: peanut soup
# Object: soup
# Predicate ID: P279
#
# Subject: fish soup
# Object: soup
# Predicate ID: P279
#
# Subject: Airbus A330
# Object: Airbus
# Predicate ID: P176
#
# Subject: Airbus A380
# Object: Airbus
# Predicate ID: P176
#
# Subject: Airbus A330neo
# Object: Airbus
# Predicate ID: P176
#
# Subject: Airbus A300
# Object: Airbus
# Predicate ID: P176
#
# Subject: Airbus A320
# Object: Airbus
# Predicate ID: P176
#
# Subject: Airbus A350
# Object: Airbus
# Predicate ID: P176
#
# Subject: Airbus A310
# Object: Airbus
# Predicate ID: P176
#
# Subject: Airbus A340
# Object: Airbus
# Predicate ID: P176
#
# Subject: Airbus A320neo family
# Object: Airbus
# Predicate ID: P176
#
# Subject: Airbus A318
# Object: Airbus
# Predicate ID: P176
#
# Subject: sociology of education
# Object: sociology
# Predicate ID: P279
#
# Subject: veterinary medicine
# Object: medicine
# Predicate ID: P279
#
# Subject: Douglas DC-1
# Object: Douglas
# Predicate ID: P176
#
# Subject: Douglas DC-5
# Object: Douglas
# Predicate ID: P176
#
# Subject: Douglas X-3 Stiletto
# Object: Douglas
# Predicate ID: P176
#
# Subject: Triumph TR2
# Object: Triumph
# Predicate ID: P176
#
# Subject: Triumph Stag
# Object: Triumph
# Predicate ID: P176
#
# Subject: Triumph GT6
# Object: Triumph
# Predicate ID: P176
#
# Subject: Triumph TR7
# Object: Triumph
# Predicate ID: P176
#
# Subject: Triumph TR4
# Object: Triumph
# Predicate ID: P176
#
# Subject: Triumph TR8
# Object: Triumph
# Predicate ID: P176
#
# Subject: Triumph Acclaim
# Object: Triumph
# Predicate ID: P176
#
# Subject: Triumph TR6
# Object: Triumph
# Predicate ID: P176
#
# Subject: Triumph 2000
# Object: Triumph
# Predicate ID: P176
#
# Subject: Triumph 1300
# Object: Triumph
# Predicate ID: P176
#
# Subject: lapdog
# Object: dog
# Predicate ID: P279
#
# Subject: Sega Pico
# Object: Sega
# Predicate ID: P176
#
# Subject: Sega Mega-CD
# Object: Sega
# Predicate ID: P176
#
# Subject: Sega 32X
# Object: Sega
# Predicate ID: P176
#
# Subject: Sega Game Gear
# Object: Sega
# Predicate ID: P176
#
# Subject: Sega Master System
# Object: Sega
# Predicate ID: P176
#
# Subject: Sega Wow
# Object: Sega
# Predicate ID: P127
#
# Subject: Sega Sports R&D
# Object: Sega
# Predicate ID: P127
#
# Subject: SegaSoft
# Object: Sega
# Predicate ID: P127
#
# Subject: Recumbent bicycle
# Object: bicycle
# Predicate ID: P279
#
# Subject: Roadster (bicycle)
# Object: bicycle
# Predicate ID: P279
#
# Subject: fixed-gear bicycle
# Object: bicycle
# Predicate ID: P279
#
# Subject: folding bicycle
# Object: bicycle
# Predicate ID: P279
#
# Subject: technical communication
# Object: communication
# Predicate ID: P279
#
# Subject: organizational communication
# Object: communication
# Predicate ID: P279
#
# Subject: Progressive Christianity
# Object: Christianity
# Predicate ID: P279
#
# Subject: descriptive statistics
# Object: statistics
# Predicate ID: P279
#
# Subject: multivariate statistics
# Object: statistics
# Predicate ID: P279
#
# Subject: folk art
# Object: art
# Predicate ID: P279
#
# Subject: culinary art
# Object: art
# Predicate ID: P279
#
# Subject: Pre-Columbian art
# Object: art
# Predicate ID: P279
#
# Subject: Korean Central News Agency
# Object: Korean
# Predicate ID: P407
#
# Subject: Bentley Turbo R
# Object: Bentley
# Predicate ID: P176
#
# Subject: Bentley T-series
# Object: Bentley
# Predicate ID: P176
#
# Subject: Bentley Arnage
# Object: Bentley
# Predicate ID: P176
#
# Subject: Bentley Continental GT
# Object: Bentley
# Predicate ID: P176
#
# Subject: Bentley Mark VI
# Object: Bentley
# Predicate ID: P176
#
# Subject: Bentley Continental Flying Spur
# Object: Bentley
# Predicate ID: P176
#
# Subject: Bentley Continental
# Object: Bentley
# Predicate ID: P176
#
# Subject: Bentley State Limousine
# Object: Bentley
# Predicate ID: P176
#
# Subject: Bentley Speed Six
# Object: Bentley
# Predicate ID: P176
#
# Subject: Yaropolk I of Kiev
# Object: Kiev
# Predicate ID: P19
#
# Subject: Adelaide Film Festival
# Object: Adelaide
# Predicate ID: P276
#
# Subject: University of Oxford
# Object: Oxford
# Predicate ID: P276
#
# Subject: Marxist feminism
# Object: feminism
# Predicate ID: P279
#
# Subject: atheist feminism
# Object: feminism
# Predicate ID: P279
#
# Subject: cultural feminism
# Object: feminism
# Predicate ID: P279
#
# Subject: health economics
# Object: economics
# Predicate ID: P279
#
# Subject: labour economics
# Object: economics
# Predicate ID: P279
#
# Subject: amateur astronomy
# Object: astronomy
# Predicate ID: P279
#
# Subject: Intel 8008
# Object: Intel
# Predicate ID: P176
#
# Subject: Intel MCS-48
# Object: Intel
# Predicate ID: P176
#
# Subject: Intel 8085
# Object: Intel
# Predicate ID: P176
#
# Subject: Catalan Wikipedia
# Object: Catalan
# Predicate ID: P407
#
# Subject: Wellington International Airport
# Object: Wellington
# Predicate ID: P138
#
# Subject: Wellington Phoenix FC
# Object: Wellington
# Predicate ID: P131
#
# Subject: Cunigunde of Luxembourg
# Object: Luxembourg
# Predicate ID: P19
#
# Subject: 2011 Libyan Civil War
# Object: Libya
# Predicate ID: P276
#
# Subject: forensic anthropology
# Object: anthropology
# Predicate ID: P279
#
# Subject: Ecological anthropology
# Object: anthropology
# Predicate ID: P279
#
# Subject: Pony car
# Object: car
# Predicate ID: P279
#
# Subject: Finnish Wikipedia
# Object: Finnish
# Predicate ID: P407
#
# Subject: 2008 Kabul Serena Hotel attack
# Object: Kabul
# Predicate ID: P276
#
# Subject: chocolate cake
# Object: cake
# Predicate ID: P279
#
# Subject: cupcake
# Object: cake
# Predicate ID: P279
#
# Subject: Harlem International Film Festival
# Object: Harlem
# Predicate ID: P276
#
# Subject: concert film
# Object: film
# Predicate ID: P279
#
# Subject: WWE NXT
# Object: WWE
# Predicate ID: P127
#
# Subject: WWE Studios
# Object: WWE
# Predicate ID: P127
#
# Subject: WWE Classics on Demand
# Object: WWE
# Predicate ID: P127
#
# Subject: smooth jazz
# Object: jazz
# Predicate ID: P279
#
# Subject: cool jazz
# Object: jazz
# Predicate ID: P279
#
# Subject: jazz fusion
# Object: jazz
# Predicate ID: P279
#
# Subject: Chester railway station
# Object: Chester
# Predicate ID: P138
#
# Subject: International Cup of Nice
# Object: Nice
# Predicate ID: P276
#
# Subject: YouTube Original Channel Initiative
# Object: YouTube
# Predicate ID: P361
#
# Subject: correspondence chess
# Object: chess
# Predicate ID: P279
#
# Subject: agroecology
# Object: ecology
# Predicate ID: P279
#
# Subject: landscape ecology
# Object: ecology
# Predicate ID: P279
#
# Subject: urban ecology
# Object: ecology
# Predicate ID: P279
#
# Subject: deep sea fish
# Object: fish
# Predicate ID: P279
#
# Subject: automatic firearm
# Object: firearm
# Predicate ID: P279
#
# Subject: aerial photography
# Object: photography
# Predicate ID: P279
#
# Subject: management accounting
# Object: accounting
# Predicate ID: P279
#
# Subject: moveable bridge
# Object: bridge
# Predicate ID: P279
#
# Subject: vehicle insurance
# Object: insurance
# Predicate ID: P279
#
# Subject: Polish Wikipedia
# Object: Polish
# Predicate ID: P407
#
# Subject: Turkish Wikipedia
# Object: Turkish
# Predicate ID: P407
#
# Subject: NBA on TNT
# Object: TNT
# Predicate ID: P449
#
# Subject: Chain pump
# Object: pump
# Predicate ID: P279
#
# Subject: carrot salad
# Object: salad
# Predicate ID: P279
#
# Subject: Hiroshima International Animation Festival
# Object: Hiroshima
# Predicate ID: P276
#
# Subject: Philips CD-i
# Object: Philips
# Predicate ID: P176
#
# Subject: Classical Armenian
# Object: Armenian
# Predicate ID: P279
#
# Subject: Samsung NX-mount
# Object: Samsung
# Predicate ID: P176
#
# Subject: Samsung NX series
# Object: Samsung
# Predicate ID: P176
#
# Subject: Samsung Life Insurance
# Object: Samsung
# Predicate ID: P361
#
# Subject: stratovolcano
# Object: volcano
# Predicate ID: P279
#
# Subject: direct democracy
# Object: democracy
# Predicate ID: P279
#
# Subject: Islam in India
# Object: Islam
# Predicate ID: P279
#
# Subject: high fantasy
# Object: fantasy
# Predicate ID: P279
#
# Subject: comic fantasy
# Object: fantasy
# Predicate ID: P279
#
# Subject: iOS 5
# Object: iOS
# Predicate ID: P279
#
# Subject: 2011 Cannes Film Festival
# Object: Cannes
# Predicate ID: P276
#
# Subject: Tate Modern
# Object: Tate
# Predicate ID: P361
#
# Subject: Yamaha YZR 500
# Object: Yamaha
# Predicate ID: P176
#
# Subject: Yamaha Royal Star Venture
# Object: Yamaha
# Predicate ID: P176
#
# Subject: Yamaha TZR250
# Object: Yamaha
# Predicate ID: P176
#
# Subject: Yamaha YZF-R1
# Object: Yamaha
# Predicate ID: P176
#
# Subject: Platonism
# Object: Plato
# Predicate ID: P138
#
# Subject: club sandwich
# Object: sandwich
# Predicate ID: P279
#
# Subject: chocolate syrup
# Object: syrup
# Predicate ID: P279
#
# Subject: Phoenix Sky Harbor International Airport
# Object: Phoenix
# Predicate ID: P276
#
# Subject: Atari 8-bit family
# Object: Atari
# Predicate ID: P176
#
# Subject: Atari Interactive
# Object: Atari
# Predicate ID: P127
#
# Subject: Nelson Airport, New Zealand
# Object: Nelson
# Predicate ID: P138
#
# Subject: over-the-horizon radar
# Object: radar
# Predicate ID: P279
#
# Subject: Pulse-Doppler radar
# Object: radar
# Predicate ID: P279
#
# Subject: uranium-234
# Object: uranium
# Predicate ID: P279
#
# Subject: Latin poetry
# Object: poetry
# Predicate ID: P279
#
# Subject: cultural geography
# Object: geography
# Predicate ID: P279
#
# Subject: mechanical television
# Object: television
# Predicate ID: P279
#
# Subject: Creole marble
# Object: marble
# Predicate ID: P279
#
# Subject: isotope of nickel
# Object: nickel
# Predicate ID: P279
#
# Subject: marine aquarium
# Object: aquarium
# Predicate ID: P279
#
# Subject: Tamil Wikipedia
# Object: Tamil
# Predicate ID: P407
#
# Subject: PGM-17 Thor
# Object: Thor
# Predicate ID: P138
#
# Subject: striated muscle tissue
# Object: muscle
# Predicate ID: P279
#
# Subject: optical telescope
# Object: telescope
# Predicate ID: P279
#
# Subject: New Haven-style pizza
# Object: pizza
# Predicate ID: P279
#
# Subject: Chicago-style pizza
# Object: pizza
# Predicate ID: P279
#
# Subject: California-style pizza
# Object: pizza
# Predicate ID: P279
#
# Subject: Prescott College
# Object: Prescott
# Predicate ID: P131
#
# Subject: Irvine High School
# Object: Irvine
# Predicate ID: P131
#
# Subject: Monofloral honey
# Object: honey
# Predicate ID: P279
#
# Subject: laminated bow
# Object: bow
# Predicate ID: P279
#
# Subject: iced tea
# Object: tea
# Predicate ID: P279
#
# Subject: Rapakivi granite
# Object: granite
# Predicate ID: P279
#
# Subject: 41xx steel
# Object: steel
# Predicate ID: P279
#
# Subject: Complementary DNA
# Object: DNA
# Predicate ID: P279
#
# Subject: antipope
# Object: pope
# Predicate ID: P279
#
# Subject: Band brake
# Object: brake
# Predicate ID: P279
#
# Subject: childhood cancer
# Object: cancer
# Predicate ID: P279
#
# Subject: democratic socialism
# Object: socialism
# Predicate ID: P279
#
# Subject: water pollution
# Object: pollution
# Predicate ID: P279
#
# Subject: nu-disco
# Object: disco
# Predicate ID: P279
#
# Subject: Italo disco
# Object: disco
# Predicate ID: P279
#
# Subject: youth suicide
# Object: suicide
# Predicate ID: P279
#
# Subject: industrial espionage
# Object: espionage
# Predicate ID: P279
#
# Subject: character actor
# Object: actor
# Predicate ID: P279
#
# Subject: bridge–tunnel
# Object: tunnel
# Predicate ID: P279
#
# Subject: Agritourism
# Object: tourism
# Predicate ID: P279
#
# Subject: Canberra International Film Festival
# Object: Canberra
# Predicate ID: P276
#
# Subject: Hammond Civic Center
# Object: Hammond
# Predicate ID: P131
#
# Subject: Czech Wikipedia
# Object: Czech
# Predicate ID: P407
#
# Subject: Hercules Graphics Card
# Object: Hercules
# Predicate ID: P176
#
# Subject: Keith railway station
# Object: Keith
# Predicate ID: P138
#
# Subject: borosilicate glass
# Object: glass
# Predicate ID: P279
#
# Subject: Chicago blues
# Object: blues
# Predicate ID: P279
#
# Subject: temperate climate
# Object: climate
# Predicate ID: P279
#
# Subject: lipstick lesbian
# Object: lesbian
# Predicate ID: P279
#
# Subject: sitting volleyball
# Object: volleyball
# Predicate ID: P279
#
# Subject: transgender female
# Object: transgender
# Predicate ID: P279
#
# Subject: political thriller
# Object: thriller
# Predicate ID: P279
#
# Subject: attending physician
# Object: physician
# Predicate ID: P279
#
# Subject: casement window
# Object: window
# Predicate ID: P279
#
# Subject: sexual addiction
# Object: addiction
# Predicate ID: P279
#
# Subject: Jazz piano
# Object: piano
# Predicate ID: P279
#
# Subject: potassium-40
# Object: potassium
# Predicate ID: P279
#
# Subject: Progress-M
# Object: Progress
# Predicate ID: P279
#
# Subject: battlecruiser
# Object: cruiser
# Predicate ID: P279
#
# Subject: computer font
# Object: font
# Predicate ID: P279
#
# Subject: deletion mutation
# Object: mutation
# Predicate ID: P279
#
# Subject: multi-purpose stadium
# Object: stadium
# Predicate ID: P279
#
# Subject: bulk density
# Object: density
# Predicate ID: P279
#
# Subject: Park golf
# Object: golf
# Predicate ID: P279
#
# Subject: Serbian nationalism
# Object: nationalism
# Predicate ID: P279
#
# Subject: Smoke grenade
# Object: grenade
# Predicate ID: P279
#
# Subject: road running
# Object: running
# Predicate ID: P279
#
# Subject: extreme poverty
# Object: poverty
# Predicate ID: P279
#
# Subject: Belgian chocolate
# Object: chocolate
# Predicate ID: P279
#
# Subject: tempo rubato
# Object: tempo
# Predicate ID: P279
#
# Subject: bacterial pneumonia
# Object: pneumonia
# Predicate ID: P279
#
# Subject: cyberterrorism
# Object: terrorism
# Predicate ID: P279
#
# Subject: Internet censorship
# Object: censorship
# Predicate ID: P279
#
# Subject: natural monopoly
# Object: monopoly
# Predicate ID: P279
#
# Subject: prison rape
# Object: rape
# Predicate ID: P279
#
# Subject: unsaturated fat
# Object: fat
# Predicate ID: P279
#
# Subject: extrasolar planet
# Object: planet
# Predicate ID: P279
#
# Subject: head teacher
# Object: teacher
# Predicate ID: P279
#
# Subject: ground beef
# Object: beef
# Predicate ID: P279
#
# Subject: laser printer
# Object: printer
# Predicate ID: P279

# %% [markdown]
# # **Task B**

# %%
# Find occurrences of the word "Paris" in 'obj_labels'
matches = df[df['obj_label'].str.contains('Paris')]

# Print the matches
print("Occurrences of the word 'Paris' in 'obj_labels':")
print(matches)
# Out:
# Occurrences of the word 'Paris' in 'obj_labels':
#     obj_label                      sub_label predicate_id  \
# 125     Paris                 Paul Delaroche          P19
# 126     Paris          Jean-Marcel Jeanneney          P19
# 127     Paris                   Henri Debain          P19
# 128     Paris            Alexandre Mercereau          P19
# 129     Paris                 Pierre Macquer          P19
# 130     Paris            Claude-Thomas Dupuy          P19
# 131     Paris              Philippe de Broca          P19
# 132     Paris                 Henri Estienne          P19
# 133     Paris                Marquis de Sade          P19
# 134     Paris                Nicolas Gigault          P19
# 135     Paris             Jacques-Jean Barre          P19
# 136     Paris                 Jules Michelet          P19
# 137     Paris                Georges Duhamel          P19
# 138     Paris                Georges Rouault          P19
# 139     Paris  Jean-Baptiste Joseph Delambre          P20
# 140     Paris        Charles-Auguste Questel          P20
# 141     Paris  Julien Augustin Joseph Mermet          P20
# 142     Paris          Jean Guillaume Moitte          P20
# 143     Paris                Jacques Derrida          P20
# 144     Paris   Jean Nicolas Pierre Hachette          P20
# 145     Paris                   Eiffel Tower         P276
# 146     Paris                       Givenchy         P740
# 147     Paris                     Montmartre         P361
#
#                      template  acc_out  \
# 125     [X] was born in [Y] .        1
# 126     [X] was born in [Y] .        1
# 127     [X] was born in [Y] .        1
# 128     [X] was born in [Y] .        1
# 129     [X] was born in [Y] .        1
# 130     [X] was born in [Y] .        1
# 131     [X] was born in [Y] .        1
# 132     [X] was born in [Y] .        1
# 133     [X] was born in [Y] .        1
# 134     [X] was born in [Y] .        1
# 135     [X] was born in [Y] .        1
# 136     [X] was born in [Y] .        1
# 137     [X] was born in [Y] .        1
# 138     [X] was born in [Y] .        1
# 139         [X] died in [Y] .        1
# 140         [X] died in [Y] .        1
# 141         [X] died in [Y] .        1
# 142         [X] died in [Y] .        1
# 143         [X] died in [Y] .        1
# 144         [X] died in [Y] .        1
# 145   [X] is located in [Y] .        1
# 146  [X] was founded in [Y] .        1
# 147      [X] is part of [Y] .        1
#
#                                               topk_IDs  \
# 125  [2201, 5, 5817, 1470, 188, 7534, 10, 4436, 631...
# 126  [2201, 5, 1470, 504, 163, 601, 23294, 6497, 10...
# 127  [2201, 5, 1470, 504, 601, 163, 23294, 6497, 10...
# 128  [2201, 5817, 5, 1470, 7534, 504, 4436, 896, 10...
# 129  [2201, 5, 1470, 504, 163, 601, 5817, 6130, 10,...
# 130  [2201, 504, 5, 1470, 601, 5817, 7534, 6130, 10...
# 131  [2201, 601, 5, 545, 504, 1470, 6497, 379, 163,...
# 132  [2201, 5, 504, 1470, 601, 10, 163, 6497, 6130,...
# 133  [2201, 5, 601, 545, 501, 379, 1470, 504, 10, 508]
# 134  [2201, 5, 1470, 5817, 504, 10, 4436, 7534, 613...
# 135  [2201, 504, 5, 1470, 5817, 7534, 601, 4436, 10...
# 136  [2201, 504, 5, 1470, 601, 6130, 23294, 4436, 1...
# 137  [2201, 1470, 5, 5817, 504, 7534, 23294, 6130, ...
# 138  [2201, 1470, 5, 504, 5817, 7534, 23294, 10, 61...
# 139  [2201, 601, 5, 504, 1789, 10, 545, 39, 1470, 1...
# 140  [2201, 504, 5, 10, 601, 39, 1470, 545, 1789, 928]
# 141  [2201, 5, 504, 10, 39, 601, 1789, 1470, 928, 545]
# 142   [2201, 5, 10, 39, 504, 601, 1470, 1789, 545, 69]
# 143  [2201, 10, 4013, 8148, 7969, 7528, 4482, 5, 61...
# 144  [2201, 39, 10, 5, 504, 1470, 1789, 601, 1098, 41]
# 145  [2201, 5, 1470, 10, 1353, 3301, 760, 65, 50118...
# 146  [2201, 504, 21868, 5, 26891, 24712, 1470, 2772...
# 147  [2201, 5, 10, 4436, 1470, 127, 188, 99, 3301, 41]
#
#                                             topk_token  \
# 125  [ Paris,  the,  Montreal,  France,  New,  Queb...
# 126  [ Paris,  the,  France,  18,  B,  17,  Marse, ...
# 127  [ Paris,  the,  France,  18,  17,  B,  Marse, ...
# 128  [ Paris,  Montreal,  the,  France,  Quebec,  1...
# 129  [ Paris,  the,  France,  18,  B,  17,  Montrea...
# 130  [ Paris,  18,  the,  France,  17,  Montreal,  ...
# 131  [ Paris,  17,  the,  16,  18,  France,  Brusse...
# 132  [ Paris,  the,  18,  France,  17,  a,  B,  Bru...
# 133  [ Paris,  the,  17,  16,  14,  15,  France,  1...
# 134  [ Paris,  the,  France,  Montreal,  18,  a,  M...
# 135  [ Paris,  18,  the,  France,  Montreal,  Quebe...
# 136  [ Paris,  18,  the,  France,  17,  Saint,  Mar...
# 137  [ Paris,  France,  the,  Montreal,  18,  Quebe...
# 138  [ Paris,  France,  the,  18,  Montreal,  Quebe...
# 139  [ Paris,  17,  the,  18,  prison,  a,  16,  hi...
# 140  [ Paris,  18,  the,  a,  17,  his,  France,  1...
# 141  [ Paris,  the,  18,  a,  his,  17,  prison,  F...
# 142  [ Paris,  the,  a,  his,  18,  17,  France,  p...
# 143  [ Paris,  a,  2005,  1994,  1995,  1997,  2004...
# 144  [ Paris,  his,  a,  the,  18,  France,  prison...
# 145  [ Paris,  the,  France,  a,  central,  downtow...
# 146  [ Paris,  18,  1947,  the,  1952,  1954,  Fran...
# 147  [ Paris,  the,  a,  Mont,  France,  my,  New, ...
#
#                                                int_IDs  \
# 125  {'0': [11, 15, 6, 8, 23, 7, 13, 25, 19, 5], '1...
# 126  {'0': [11, 15, 6, 8, 23, 13, 7, 5, 19, 10], '1...
# 127  {'0': [11, 15, 6, 8, 23, 7, 13, 25, 19, 5], '1...
# 128  {'0': [11, 15, 6, 8, 23, 7, 13, 36, 10, 19], '...
# 129  {'0': [11, 15, 6, 8, 23, 7, 13, 36, 4, 12], '1...
# 130  {'0': [11, 15, 8, 23, 6, 13, 7, 19, 5, 9], '1'...
# 131  {'0': [11, 15, 6, 8, 23, 7, 13, 36, 10, 19], '...
# 132  {'0': [11, 15, 6, 8, 23, 7, 13, 25, 19, 5], '1...
# 133  {'0': [11, 15, 8, 23, 6, 13, 7, 19, 5, 9], '1'...
# 134  {'0': [11, 15, 6, 8, 23, 7, 13, 25, 19, 5], '1...
# 135  {'0': [11, 15, 8, 23, 6, 13, 7, 19, 5, 9], '1'...
# 136  {'0': [11, 15, 6, 8, 23, 7, 13, 25, 19, 5], '1...
# 137  {'0': [11, 15, 6, 8, 23, 7, 13, 36, 10, 19], '...
# 138  {'0': [11, 15, 6, 8, 23, 7, 13, 25, 19, 5], '1...
# 139  {'0': [11, 15, 6, 8, 23, 13, 7, 5, 19, 10], '1...
# 140  {'0': [11, 15, 6, 8, 23, 7, 13, 36, 10, 19], '...
# 141  {'0': [11, 15, 8, 23, 6, 13, 7, 19, 5, 9], '1'...
# 142  {'0': [11, 15, 6, 8, 23, 7, 13, 36, 10, 19], '...
# 143  {'0': [11, 15, 6, 8, 23, 7, 13, 25, 19, 5], '1...
# 144  {'0': [11, 15, 8, 23, 6, 13, 7, 19, 5, 9], '1'...
# 145  {'0': [11, 15, 6, 8, 23, 7, 13, 25, 19, 5], '1...
# 146  {'0': [11, 15, 6, 8, 23, 7, 13, 10, 19, 9], '1...
# 147  {'0': [9, 1116, 6, 1525, 8, 12, 11, 4, 36, 15]...
#
#                                             int_tokens
# 125  {'0': [' in', ' on', ',', ' and', ' at', ' to'...
# 126  {'0': [' in', ' on', ',', ' and', ' at', ' for...
# 127  {'0': [' in', ' on', ',', ' and', ' at', ' to'...
# 128  {'0': [' in', ' on', ',', ' and', ' at', ' to'...
# 129  {'0': [' in', ' on', ',', ' and', ' at', ' to'...
# 130  {'0': [' in', ' on', ' and', ' at', ',', ' for...
# 131  {'0': [' in', ' on', ',', ' and', ' at', ' to'...
# 132  {'0': [' in', ' on', ',', ' and', ' at', ' to'...
# 133  {'0': [' in', ' on', ' and', ' at', ',', ' for...
# 134  {'0': [' in', ' on', ',', ' and', ' at', ' to'...
# 135  {'0': [' in', ' on', ' and', ' at', ',', ' for...
# 136  {'0': [' in', ' on', ',', ' and', ' at', ' to'...
# 137  {'0': [' in', ' on', ',', ' and', ' at', ' to'...
# 138  {'0': [' in', ' on', ',', ' and', ' at', ' to'...
# 139  {'0': [' in', ' on', ',', ' and', ' at', ' for...
# 140  {'0': [' in', ' on', ',', ' and', ' at', ' to'...
# 141  {'0': [' in', ' on', ' and', ' at', ',', ' for...
# 142  {'0': [' in', ' on', ',', ' and', ' at', ' to'...
# 143  {'0': [' in', ' on', ',', ' and', ' at', ' to'...
# 144  {'0': [' in', ' on', ' and', ' at', ',', ' for...
# 145  {'0': [' in', ' on', ',', ' and', ' at', ' to'...
# 146  {'0': [' in', ' on', ',', ' and', ' at', ' to'...
# 147  {'0': [' of', 'of', ',', ' Of', ' and', '-', '...

# %%
#  Find at what layer the 'object' token is present for the first time in the top 10 tokens

# Iterate through each row
for index, row in df.iterrows():
    int_tokens = row['int_tokens']
    # Iterate through each layer
    for layer, tokens in int_tokens.items():
        # Check if 'Paris' is in the tokens of this layer
        if ' Paris' in tokens:
            # Extract the layer number from the key
            first_appearance_layer = int(layer)
            print(f"The object 'Paris' first appears in layer {first_appearance_layer}.")
            break
# Out:
# The object 'Paris' first appears in layer 22.
# The object 'Paris' first appears in layer 20.
# The object 'Paris' first appears in layer 20.
# The object 'Paris' first appears in layer 20.
# The object 'Paris' first appears in layer 20.
# The object 'Paris' first appears in layer 20.
# The object 'Paris' first appears in layer 20.
# The object 'Paris' first appears in layer 20.
# The object 'Paris' first appears in layer 20.
# The object 'Paris' first appears in layer 20.
# The object 'Paris' first appears in layer 20.
# The object 'Paris' first appears in layer 20.
# The object 'Paris' first appears in layer 20.
# The object 'Paris' first appears in layer 20.
# The object 'Paris' first appears in layer 20.
# The object 'Paris' first appears in layer 21.
# The object 'Paris' first appears in layer 20.
# The object 'Paris' first appears in layer 20.
# The object 'Paris' first appears in layer 21.
# The object 'Paris' first appears in layer 20.
# The object 'Paris' first appears in layer 20.
# The object 'Paris' first appears in layer 19.
# The object 'Paris' first appears in layer 19.
# The object 'Paris' first appears in layer 19.
# The object 'Paris' first appears in layer 21.
# The object 'Paris' first appears in layer 20.
# The object 'Paris' first appears in layer 20.
# The object 'Paris' first appears in layer 22.
# The object 'Paris' first appears in layer 22.
# The object 'Paris' first appears in layer 20.
# The object 'Paris' first appears in layer 24.
# The object 'Paris' first appears in layer 20.
# The object 'Paris' first appears in layer 20.
# The object 'Paris' first appears in layer 24.
# The object 'Paris' first appears in layer 21.
# The object 'Paris' first appears in layer 20.

# %%
# Find at what layer the 'object' token is top 1 in for the first time
for index, row in df.iterrows():
    int_tokens = row['int_tokens']
    # Iterate through each layer
    for layer, tokens in int_tokens.items():
        # Check if 'Paris' is in the tokens of this layer
        if ' Paris' in tokens[0]:
            # Extract the layer number from the key
            top_token_layer = int(layer)
            print(f"The object 'Paris' is top token in layer {top_token_layer}.")
            break
# Out:
# The object 'Paris' is top token in layer 24.
# The object 'Paris' is top token in layer 23.
# The object 'Paris' is top token in layer 23.
# The object 'Paris' is top token in layer 23.
# The object 'Paris' is top token in layer 23.
# The object 'Paris' is top token in layer 23.
# The object 'Paris' is top token in layer 23.
# The object 'Paris' is top token in layer 24.
# The object 'Paris' is top token in layer 24.
# The object 'Paris' is top token in layer 23.
# The object 'Paris' is top token in layer 24.
# The object 'Paris' is top token in layer 23.
# The object 'Paris' is top token in layer 23.
# The object 'Paris' is top token in layer 23.
# The object 'Paris' is top token in layer 22.
# The object 'Paris' is top token in layer 23.
# The object 'Paris' is top token in layer 22.
# The object 'Paris' is top token in layer 23.
# The object 'Paris' is top token in layer 22.
# The object 'Paris' is top token in layer 22.
# The object 'Paris' is top token in layer 21.
# The object 'Paris' is top token in layer 22.
# The object 'Paris' is top token in layer 20.
